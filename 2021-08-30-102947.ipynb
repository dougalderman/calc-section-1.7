# %%
derivative((x/(x-1)^0.5)^3)
# Out:
# 3*x^2/(x - 1)^1.50000000000000 - 1.50000000000000*x^3/(x - 1)^2.50000000000000

# %%
derivative(((x^2-x-1)/(x^2+1))^3)
# Out:
# 3*(x^2 - x - 1)^2*(2*x - 1)/(x^2 + 1)^3 - 6*(x^2 - x - 1)^3*x/(x^2 + 1)^4

# %%
derivative(4*x/(x-10)^0.5)
# Out:
# 4/sqrt(x - 10) - 2.00000000000000*x/(x - 10)^1.50000000000000

# %%
show(plot(3*(x^2 - x - 1)^2*(2*x - 1)/(x^2 + 1)^3 - 6*(x^2 - x - 1)^3*x/(x^2 + 1)^4
, x, xmin=-3, xmax=3), ymin=-10, ymax=10)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
show(plot((3*(x^2-x-1)^2*(x^2+4*x-1))/(x^2+1)^4
, x, xmin=-3, xmax=3), ymin=-10, ymax=10)
# Out:
# Graphics object consisting of 1 graphics primitive
